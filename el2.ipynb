# %%
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.011870     0.006082     0.011870   142.052592
# std       0.015015     0.137956     0.074374     0.137956  1650.922420
# min      -0.026000    -0.257917    -0.104255    -0.248616 -2975.188510
# 25%      -0.013006    -0.101133    -0.076114    -0.051631  -617.869972
# 50%      -0.000013    -0.004650     0.019363     0.004650    55.649661
# 75%       0.012980     0.051631     0.078660     0.101133  1210.254662
# max       0.025974     0.248616     0.102780     0.257917  3086.487833
#
#                  B
# count  2000.000000
# mean      0.036493
# std       0.446246
# min      -0.625530
# 25%      -0.456686
# 50%       0.116178
# 75%       0.471957
# max       0.616681

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

t = np.linspace(-10, 10, 100)
sig = 1 / (1 + np.exp(-t))

plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0.5, color="black", linestyle=":")
plt.axhline(y=1.0, color="black", linestyle="--")
plt.axvline(color="grey")
plt.plot(t, sig, linewidth=2, label=r"$\sigma(t) = \frac{1}{1 + e^{-t}}$")
plt.xlim(-10, 10)
plt.xlabel("t")
plt.legend(fontsize=14)
plt.show()

# %%
# 0
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_0.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.011870     0.006082     0.011870    83.092516
# std       0.015015     0.137956     0.074374     0.137956   965.693736
# min      -0.026000    -0.257917    -0.104255    -0.248616 -1740.312490
# 25%      -0.013006    -0.101133    -0.076114    -0.051631  -361.418050
# 50%      -0.000013    -0.004650     0.019363     0.004650    32.551820
# 75%       0.012980     0.051631     0.078660     0.101133   707.928690
# max       0.025974     0.248616     0.102780     0.257917  1805.416130
#
#                  B
# count  2000.000000
# mean      0.036493
# std       0.446246
# min      -0.625530
# 25%      -0.456686
# 50%       0.116178
# 75%       0.471957
# max       0.616681

# %%
# 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_1.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.008751     0.006467     0.008751   104.726708
# std       0.015015     0.298737     0.075727     0.298737  3574.987847
# min      -0.026000    -0.504088    -0.108275    -0.500937 -5994.714874
# 25%      -0.013006    -0.262882    -0.076114    -0.239631 -2867.659630
# 50%      -0.000013    -0.001575     0.022378     0.001575    18.852931
# 75%       0.012980     0.239631     0.080670     0.262882  3145.908176
# max       0.025974     0.500937     0.104790     0.504088  6032.420737
#
#                  B
# count  2000.000000
# mean      0.038803
# std       0.454360
# min      -0.649651
# 25%      -0.456686
# 50%       0.134269
# 75%       0.484018
# max       0.628741

# %%
# 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_2.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.016822     0.004996     0.016822   201.304607
# std       0.015015     0.439641     0.077161     0.439641  5261.188610
# min      -0.026000    -0.705093    -0.108275    -0.701942 -8400.141948
# 25%      -0.013006    -0.423686    -0.078124    -0.350183 -4190.644508
# 50%      -0.000013    -0.001575     0.023383     0.001575    18.852931
# 75%       0.012980     0.350183     0.078660     0.423686  5070.249883
# max       0.025974     0.701942     0.106800     0.705093  8437.847811
#
#                  B
# count  2000.000000
# mean      0.029977
# std       0.462966
# min      -0.649651
# 25%      -0.468746
# 50%       0.140299
# 75%       0.471957
# max       0.640802

# %%
# 3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_3.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013    -0.020892     0.000712     0.020892    250.014503
# std       0.015015     0.651042     0.078339     0.651042   7791.023989
# min      -0.026000    -1.006601    -0.116048    -0.983349 -11767.739876
# 25%      -0.013006    -0.644791    -0.083887    -0.541138  -6475.800241
# 50%      -0.000013    -0.001575     0.020636     0.001575     18.852931
# 75%       0.012980     0.541138     0.076917     0.644791   7716.219761
# max       0.025974     0.983349     0.105058     1.006601  12045.988543
#
#                  B
# count  2000.000000
# mean      0.004272
# std       0.470032
# min      -0.696286
# 25%      -0.503322
# 50%       0.123814
# 75%       0.461502
# max       0.630347

# %%
# 4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_4.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013    -0.018638     0.000673     0.018638    223.044076
# std       0.015015     0.911383     0.078777     0.911383  10906.525223
# min      -0.026000    -1.369985    -0.116048    -1.363683 -16319.198410
# 25%      -0.013006    -0.927774    -0.083887    -0.825995  -9884.680908
# 50%      -0.000013    -0.003151     0.020636     0.003151     37.705863
# 75%       0.012980     0.825995     0.076917     0.927774  11102.670620
# max       0.025974     1.363683     0.105058     1.369985  16394.610256
#
#                  B
# count  2000.000000
# mean      0.004037
# std       0.472659
# min      -0.696286
# 25%      -0.503322
# 50%       0.123814
# 75%       0.461502
# max       0.630347

# %%
# 5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_5.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013    -0.013915    -0.000259     0.013915    166.516536
# std       0.015015     1.063318     0.078801     1.063318  12724.727485
# min      -0.026000    -1.570990    -0.114038    -1.564688 -18724.625484
# 25%      -0.013006    -1.088578    -0.083887    -1.001874 -11989.429628
# 50%      -0.000013    -0.003151     0.020636     0.003151     37.705863
# 75%       0.012980     1.001874     0.076917     1.088578  13027.012328
# max       0.025974     1.564688     0.105058     1.570990  18800.037330
#
#                  B
# count  2000.000000
# mean     -0.001553
# std       0.472808
# min      -0.684226
# 25%      -0.503322
# 50%       0.123814
# 75%       0.461502
# max       0.630347

# %%
# 6
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_6.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013    -0.005814    -0.000152     0.005814     69.577828
# std       0.015015     1.325146     0.077709     1.325146  15858.019838
# min      -0.026000    -1.932799    -0.112028    -1.926497 -23054.394386
# 25%      -0.013006    -1.329784    -0.081877    -1.283281 -15357.027556
# 50%      -0.000013    -0.003151     0.013601     0.003151     37.705863
# 75%       0.012980     1.283281     0.074907     1.329784  15913.524889
# max       0.025974     1.926497     0.105058     1.932799  23129.806112
#
#                  B
# count  2000.000000
# mean     -0.000914
# std       0.466255
# min      -0.672166
# 25%      -0.491261
# 50%       0.081603
# 75%       0.449442
# max       0.630347

# %%
# 7
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_7.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.013005     0.002425     0.013005   155.625022
# std       0.015015     0.199567     0.075179     0.199567  2388.221409
# min      -0.026000    -0.346259    -0.112028    -0.337158 -4034.773376
# 25%      -0.013006    -0.169374    -0.079867    -0.113038 -1352.722096
# 50%      -0.000013    -0.002540     0.014606     0.002540    30.398454
# 75%       0.012980     0.113038     0.076917     0.169374  2026.902966
# max       0.025974     0.337158     0.101038     0.346259  4143.678820
#
#                  B
# count  2000.000000
# mean      0.014548
# std       0.451074
# min      -0.672166
# 25%      -0.479201
# 50%       0.087633
# 75%       0.461502
# max       0.606226

# %%
# 8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_8.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1            H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.000013    -0.010304     0.002584     0.010304   123.308631
# std       0.015015     0.419320     0.076146     0.419320  5018.006610
# min      -0.026000    -0.644791    -0.108008    -0.681842 -8159.599265
# 25%      -0.013006    -0.423686    -0.077857    -0.372796 -4461.255027
# 50%      -0.000013    -0.001575     0.008575     0.001575    18.852931
# 75%       0.012980     0.372796     0.078927     0.423686  5070.249883
# max       0.025974     0.681842     0.107068     0.644791  7716.219761
#
#                  B
# count  2000.000000
# mean      0.015507
# std       0.456878
# min      -0.648045
# 25%      -0.467141
# 50%       0.051452
# 75%       0.473563
# max       0.642407

# %%
# 9
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_9.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
# df['nu'] = df['H'] / df['B']
fig, ax = plt.subplots()

ax.set(ylabel='B, Тл', xlabel='Н, А/м')
ax.grid()
ax.scatter(df['H'], df['B'], s=4)
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013     0.000548     0.002391    -0.000548     -6.553944
# std       0.015015     0.773282     0.077397     0.773282   9253.863308
# min      -0.026000    -1.148879    -0.112028    -1.202879 -14394.856703
# 25%      -0.013006    -0.766970    -0.079867    -0.740568  -8862.374384
# 50%      -0.000013    -0.003151     0.009580     0.003151     37.705863
# 75%       0.012980     0.740568     0.078927     0.766970   9178.328913
# max       0.025974     1.202879     0.109078     1.148879  13748.640498
#
#                  B
# count  2000.000000
# mean      0.014349
# std       0.464379
# min      -0.672166
# 25%      -0.479201
# 50%       0.057482
# 75%       0.473563
# max       0.654467

# %%
# 10
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker


df = pd.read_csv('el_10.csv', sep=',')
df['minus_1'] = df['1'] * (-1)
df['H'] = df['minus_1'] * 11967
df['B'] = df['2'] * 6
# df.describe()
df['nu'] = df['B'] / df['H'] * 0.08 *10**7
fig, ax = plt.subplots()

ax.set(ylabel='mu', xlabel='Н, А/м')
ax.grid()
plt.plot(df['H'], df['nu'])
df.describe()
# Out:
#             x-axis            1            2      minus_1             H  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     -0.000013    -0.000417     0.001741     0.000417      4.992107
# std       0.015015     1.115716     0.078365     1.115716  13351.776005
# min      -0.026000    -1.611191    -0.112028    -1.685291 -20167.881825
# 25%      -0.013006    -1.108678    -0.079867    -1.062176 -12711.057799
# 50%      -0.000013     0.016950     0.012595    -0.016950   -202.836821
# 75%       0.012980     1.062176     0.080937     1.108678  13267.555011
# max       0.025974     1.685291     0.109078     1.611191  19281.122817
#
#                  B           nu
# count  2000.000000  2000.000000
# mean      0.010447    13.588782
# std       0.470192   599.217842
# min      -0.672166 -8631.849761
# 25%      -0.479201    22.260823
# 50%       0.075573    25.420910
# 75%       0.485623    32.203994
# max       0.654467  8512.224863

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker
d1 = pd.DataFrame({'B':[0.616681, 0.628741,0.640802,0.630347,0.630347,0.630347,0.630347,0.606226,0.642407,0.654467,0.654467], 
              'H':[3086.487833,6032.420737,8437.847811,12045.988543,16394.610256,18800.037330,23129.806112,4143.678820,7716.219761,13748.640498,19281.122817]})
d1['nu'] = (d1['B'] / (d1['H'] * 4 * math.pi )) * 10**7
fig, ax = plt.subplots()

ax.set(ylabel='mu', xlabel='Н, А/м')
ax.grid()
ax.scatter(d1['H'], d1['nu'])
